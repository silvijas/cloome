# %%
import numpy as np
import os

import pandas as pd

import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Cropping images

# %%
def split_npz_file_into_16_parts(npz_file_path, output_dir):
    npz_data = np.load(npz_file_path, allow_pickle=True)
    
    sample = npz_data['sample']                   # Extracting image and metadata for it
    channels = npz_data['channels'].item()  
    filenames = npz_data['filenames'].item()
    
    img_height, img_width, num_channels = sample.shape  # Expecting (2500, 2500, 5)
   # print(f"(img_height, img_width, num_channels)=({img_height}, {img_width}, {num_channels})")
    
    tile_height = img_height // 4
    tile_width = img_width // 4
    
    for i in range(4):  
        for j in range(4):  
            split_sample = np.zeros((tile_height, tile_width, num_channels), dtype=sample.dtype)
            
            for c in range(num_channels):
                split_sample[:, :, c] = sample[i * tile_height:(i + 1) * tile_height,
                                               j * tile_width:(j + 1) * tile_width,
                                               c]
            
            base_name = os.path.splitext(os.path.basename(npz_file_path))[0]
            split_filename = f"{base_name}_part_{i}_{j}.npz"
            split_file_path = os.path.join(output_dir, split_filename)
            
            np.savez(split_file_path, sample=split_sample, channels=channels, filenames=filenames)
    
    print(f"Splitting and saving completed for {npz_file_path}.")

# %%
input_dir = '/share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full'
output_dir = '/share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz'  
os.makedirs(output_dir, exist_ok=True)

npz_files = [f for f in os.listdir(input_dir) if f.endswith('.npz')]

for npz_file in npz_files:
    path = input_dir + "/" + npz_file
#    print(path)
    split_npz_file_into_16_parts(path, output_dir)
# Out:
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-1.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-2.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-3.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-4.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-5.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-6.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-7.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-8.npz.
# Splitting and saving completed for /share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz_full/P102785-A02-9.npz.

# %%
# Checking if dimensions are good
npz_data = np.load("/share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/channels_tiff_npz/P102785-A02-1_part_0_0.npz", allow_pickle=True)
    
sample = npz_data['sample']  
channels = npz_data['channels'].item()  
filenames = npz_data['filenames'].item()
    
img_height, img_width, num_channels = sample.shape  # Expecting (2500, 2500, 5)
print(f"(img_height, img_width, num_channels)=({img_height}, {img_width}, {num_channels})")
# Out:
# (img_height, img_width, num_channels)=(625, 625, 5)

# %% [markdown]
# # Manipulating metadata file

# %%
metadata_file = '/share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_all/metadata_P102785_ALL.csv'
metadata_df = pd.read_csv(metadata_file)
    
positions = [(i, j) for i in range(4) for j in range(4)]

expanded_rows = []
for _, row in metadata_df.iterrows():
    for i, j in positions:
        new_row = row.copy()
        new_row['CROP_POS'] = f"{i}-{j}"
        expanded_rows.append(new_row)

expanded_metadata_df = pd.DataFrame(expanded_rows)

site_index = expanded_metadata_df.columns.get_loc('SITE')
expanded_metadata_df.insert(site_index + 1, 'CROP_POS', expanded_metadata_df.pop('CROP_POS'))

#print(expanded_metadata_df)

expanded_metadata_df.to_csv("/share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_crop/metadata_P102785_ALL.csv", index=False)

# %%
# Renaming for testing if it will work only with one crop 

odir = '/share/data/analyses/silvija/RT/data_cloome/our_images/preprocessing_all_singleCrop/channels_tiff_npz'  
os.makedirs(odir, exist_ok=True)

npz_files = [f for f in os.listdir(odir) if f.endswith('.npz')]

for npz_file in npz_files:
    parts = npz_file.split("-")
    name = "-".join(parts[:-2]) + ".npz"
    
    old_path = odir + "/" + npz_file
    new_path = odir + "/" + name

    os.rename(old_path, new_path)
    print(f"Renamed : {name}")
# Out:
# Renamed : P102785-A10-6.npz
# Renamed : P102785-A19-4.npz
# Renamed : P102785-C05-7.npz
# Renamed : P102785-C10-2.npz
# Renamed : P102785-C10-8.npz
# Renamed : P102785-C15-6.npz
# Renamed : P102785-C24-1.npz
# Renamed : P102785-C24-9.npz
# Renamed : P102785-D06-4.npz
# Renamed : P102785-D19-7.npz
# Renamed : P102785-D19-9.npz
# Renamed : P102785-D22-9.npz
# Renamed : P102785-D23-8.npz
# Renamed : P102785-E03-1.npz
# Renamed : P102785-E03-2.npz
# Renamed : P102785-E06-7.npz
# Renamed : P102785-E06-8.npz
# Renamed : P102785-E06-9.npz
# Renamed : P102785-E12-1.npz
# Renamed : P102785-F10-9.npz
# Renamed : P102785-F12-4.npz
# Renamed : P102785-F14-3.npz
# Renamed : P102785-F17-6.npz
# Renamed : P102785-G08-3.npz
# Renamed : P102785-G11-4.npz
# Renamed : P102785-G20-2.npz
# Renamed : P102785-G20-6.npz
# Renamed : P102785-G20-8.npz
# Renamed : P102785-G24-7.npz
# Renamed : P102785-H18-5.npz
# Renamed : P102785-H18-8.npz
# Renamed : P102785-H22-2.npz
# Renamed : P102785-H22-5.npz
# Renamed : P102785-H22-6.npz
# Renamed : P102785-I06-3.npz
# Renamed : P102785-I06-6.npz
# Renamed : P102785-I08-9.npz
# Renamed : P102785-I10-6.npz
# Renamed : P102785-I10-7.npz
# Renamed : P102785-I24-1.npz
# Renamed : P102785-J12-5.npz
# Renamed : P102785-J12-8.npz
# Renamed : P102785-J13-7.npz
# Renamed : P102785-J13-8.npz
# Renamed : P102785-J24-3.npz
# Renamed : P102785-K02-2.npz
# Renamed : P102785-K17-7.npz
# Renamed : P102785-K21-5.npz
# Renamed : P102785-K23-2.npz
# Renamed : P102785-K23-5.npz
# Renamed : P102785-L07-1.npz
# Renamed : P102785-L19-1.npz
# Renamed : P102785-L19-4.npz
# Renamed : P102785-L19-6.npz
# Renamed : P102785-L19-8.npz
# Renamed : P102785-L19-9.npz
# Renamed : P102785-L20-2.npz
# Renamed : P102785-L20-6.npz
# Renamed : P102785-M09-7.npz
# Renamed : P102785-M10-1.npz
# Renamed : P102785-M13-6.npz
# Renamed : P102785-N12-1.npz
# Renamed : P102785-N12-2.npz
# Renamed : P102785-N12-3.npz
# Renamed : P102785-N13-1.npz
# Renamed : P102785-N13-6.npz
# Renamed : P102785-N16-6.npz
# Renamed : P102785-N16-7.npz
# Renamed : P102785-N17-8.npz
# Renamed : P102785-N17-9.npz
# Renamed : P102785-O15-3.npz
# Renamed : P102785-O21-3.npz
# Renamed : P102785-O21-9.npz
# Renamed : P102785-P04-1.npz
# Renamed : P102785-P04-2.npz
# Renamed : P102785-P04-7.npz
# Renamed : P102785-P10-2.npz
# Renamed : P102785-D22-1.npz
# Renamed : P102785-C05-9.npz
# Renamed : P102785-D19-5.npz
# Renamed : P102785-C05-1.npz
# Renamed : P102785-D21-5.npz
# Renamed : P102785-A19-5.npz
# Renamed : P102785-E06-1.npz
# Renamed : P102785-D19-6.npz
# Renamed : P102785-A19-7.npz
# Renamed : P102785-A19-8.npz
# Renamed : P102785-C05-2.npz
# Renamed : P102785-C24-2.npz
# Renamed : P102785-E03-8.npz
# Renamed : P102785-B07-5.npz
# Renamed : P102785-D21-1.npz
# Renamed : P102785-D23-5.npz
# Renamed : P102785-A02-5.npz
# Renamed : P102785-E06-5.npz
# Renamed : P102785-E12-3.npz
# Renamed : P102785-E12-8.npz
# Renamed : P102785-F03-6.npz
# Renamed : P102785-F10-6.npz
# Renamed : P102785-F14-9.npz
# Renamed : P102785-F16-1.npz
# Renamed : P102785-F16-9.npz
# Renamed : P102785-F17-1.npz
# Renamed : P102785-F17-4.npz
# Renamed : P102785-G08-4.npz
# Renamed : P102785-G08-9.npz
# Renamed : P102785-G20-1.npz
# Renamed : P102785-G22-1.npz
# Renamed : P102785-G22-5.npz
# Renamed : P102785-G24-9.npz
# Renamed : P102785-H04-3.npz
# Renamed : P102785-H04-7.npz
# Renamed : P102785-H18-3.npz
# Renamed : P102785-I06-2.npz
# Renamed : P102785-I08-3.npz
# Renamed : P102785-I10-3.npz
# Renamed : P102785-J10-8.npz
# Renamed : P102785-J12-6.npz
# Renamed : P102785-J13-1.npz
# Renamed : P102785-J13-5.npz
# Renamed : P102785-J24-8.npz
# Renamed : P102785-K01-2.npz
# Renamed : P102785-K01-6.npz
# Renamed : P102785-K02-7.npz
# Renamed : P102785-K17-4.npz
# Renamed : P102785-K17-6.npz
# Renamed : P102785-K21-2.npz
# Renamed : P102785-K23-1.npz
# Renamed : P102785-L05-5.npz
# Renamed : P102785-L07-4.npz
# Renamed : P102785-L20-4.npz
# Renamed : P102785-M09-4.npz
# Renamed : P102785-M13-7.npz
# Renamed : P102785-N12-5.npz
# Renamed : P102785-N13-8.npz
# Renamed : P102785-N16-5.npz
# Renamed : P102785-N17-1.npz
# Renamed : P102785-O15-6.npz
# Renamed : P102785-O21-4.npz
# Renamed : P102785-P03-9.npz
# Renamed : P102785-P04-8.npz
# Renamed : P102785-P09-4.npz
# Renamed : P102785-P09-9.npz
# Renamed : P102785-P10-1.npz
# Renamed : P102785-P10-5.npz
# Renamed : P102785-P10-6.npz
# Renamed : P102785-P21-2.npz
# Renamed : P102785-P21-3.npz
# Renamed : P102785-P21-8.npz
# Renamed : P102785-B07-3.npz
# Renamed : P102785-F14-5.npz
# Renamed : P102785-F17-3.npz
# Renamed : P102785-F03-4.npz
# Renamed : P102785-G22-7.npz
# Renamed : P102785-A02-3.npz
# Renamed : P102785-F09-5.npz
# Renamed : P102785-D23-6.npz
# Renamed : P102785-D06-8.npz
# Renamed : P102785-E06-6.npz
# Renamed : P102785-F16-5.npz
# Renamed : P102785-A19-6.npz
# Renamed : P102785-F15-8.npz
# Renamed : P102785-F16-7.npz
# Renamed : P102785-D06-1.npz
# Renamed : P102785-F09-9.npz
# Renamed : P102785-F12-7.npz
# Renamed : P102785-E12-4.npz
# Renamed : P102785-C10-3.npz
# Renamed : P102785-D19-4.npz
# Renamed : P102785-A02-6.npz
# Renamed : P102785-F12-9.npz
# Renamed : P102785-E03-9.npz
# Renamed : P102785-F10-8.npz
# Renamed : P102785-C24-6.npz
# Renamed : P102785-F03-3.npz
# Renamed : P102785-F15-3.npz
# Renamed : P102785-G24-3.npz
# Renamed : P102785-H04-6.npz
# Renamed : P102785-H04-8.npz
# Renamed : P102785-H18-2.npz
# Renamed : P102785-H22-1.npz
# Renamed : P102785-H22-7.npz
# Renamed : P102785-H22-8.npz
# Renamed : P102785-I06-5.npz
# Renamed : P102785-I06-7.npz
# Renamed : P102785-I08-4.npz
# Renamed : P102785-I24-5.npz
# Renamed : P102785-I24-7.npz
# Renamed : P102785-I24-8.npz
# Renamed : P102785-J10-4.npz
# Renamed : P102785-J10-5.npz
# Renamed : P102785-J12-1.npz
# Renamed : P102785-J13-3.npz
# Renamed : P102785-J24-7.npz
# Renamed : P102785-K01-7.npz
# Renamed : P102785-K01-8.npz
# Renamed : P102785-K02-8.npz
# Renamed : P102785-K16-6.npz
# Renamed : P102785-K17-8.npz
# Renamed : P102785-K17-9.npz
# Renamed : P102785-K21-3.npz
# Renamed : P102785-K23-3.npz
# Renamed : P102785-K23-7.npz
# Renamed : P102785-K23-8.npz
# Renamed : P102785-L05-4.npz
# Renamed : P102785-L05-6.npz
# Renamed : P102785-L05-9.npz
# Renamed : P102785-L07-3.npz
# Renamed : P102785-L20-1.npz
# Renamed : P102785-L20-7.npz
# Renamed : P102785-M09-3.npz
# Renamed : P102785-M10-7.npz
# Renamed : P102785-M10-8.npz
# Renamed : P102785-M13-9.npz
# Renamed : P102785-N12-8.npz
# Renamed : P102785-N13-9.npz
# Renamed : P102785-N17-3.npz
# Renamed : P102785-N17-5.npz
# Renamed : P102785-O15-2.npz
# Renamed : P102785-O15-5.npz
# Renamed : P102785-O21-6.npz
# Renamed : P102785-P03-3.npz
# Renamed : P102785-P04-5.npz
# Renamed : P102785-P21-5.npz
# Renamed : P102785-G22-8.npz
# Renamed : P102785-G22-3.npz
# Renamed : P102785-F09-4.npz
# Renamed : P102785-B07-9.npz
# Renamed : P102785-G22-6.npz
# Renamed : P102785-D22-7.npz
# Renamed : P102785-F10-7.npz
# Renamed : P102785-E03-3.npz
# Renamed : P102785-F15-2.npz
# Renamed : P102785-D21-4.npz
# Renamed : P102785-D23-1.npz
# Renamed : P102785-F10-1.npz
# Renamed : P102785-G22-2.npz
# Renamed : P102785-A10-1.npz
# Renamed : P102785-C10-4.npz
# Renamed : P102785-E12-6.npz
# Renamed : P102785-D21-6.npz
# Renamed : P102785-C15-1.npz
# Renamed : P102785-F12-2.npz
# Renamed : P102785-D22-6.npz
# Renamed : P102785-E03-7.npz
# Renamed : P102785-E06-3.npz
# Renamed : P102785-B07-7.npz
# Renamed : P102785-C15-4.npz
# Renamed : P102785-C10-5.npz
# Renamed : P102785-D19-8.npz
# Renamed : P102785-F17-7.npz
# Renamed : P102785-F12-6.npz
# Renamed : P102785-E12-9.npz
# Renamed : P102785-G11-3.npz
# Renamed : P102785-G24-6.npz
# Renamed : P102785-H18-1.npz
# Renamed : P102785-H22-3.npz
# Renamed : P102785-I08-2.npz
# Renamed : P102785-I08-7.npz
# Renamed : P102785-I10-2.npz
# Renamed : P102785-I24-9.npz
# Renamed : P102785-J10-6.npz
# Renamed : P102785-J12-2.npz
# Renamed : P102785-J12-4.npz
# Renamed : P102785-J13-4.npz
# Renamed : P102785-J24-4.npz
# Renamed : P102785-J24-6.npz
# Renamed : P102785-J24-9.npz
# Renamed : P102785-K01-5.npz
# Renamed : P102785-K02-3.npz
# Renamed : P102785-K02-5.npz
# Renamed : P102785-K21-7.npz
# Renamed : P102785-L05-3.npz
# Renamed : P102785-L05-8.npz
# Renamed : P102785-L07-5.npz
# Renamed : P102785-L07-9.npz
# Renamed : P102785-L19-5.npz
# Renamed : P102785-L20-5.npz
# Renamed : P102785-L20-8.npz
# Renamed : P102785-M09-1.npz
# Renamed : P102785-M09-2.npz
# Renamed : P102785-M09-5.npz
# Renamed : P102785-M10-5.npz
# Renamed : P102785-M13-2.npz
# Renamed : P102785-N13-4.npz
# Renamed : P102785-N13-5.npz
# Renamed : P102785-N17-4.npz
# Renamed : P102785-P03-5.npz
# Renamed : P102785-P04-4.npz
# Renamed : P102785-P09-2.npz
# Renamed : P102785-P09-7.npz
# Renamed : P102785-P21-4.npz
# Renamed : P102785-F17-8.npz
# Renamed : P102785-I24-2.npz
# Renamed : P102785-C10-6.npz
# Renamed : P102785-I10-5.npz
# Renamed : P102785-L19-7.npz
# Renamed : P102785-F03-7.npz
# Renamed : P102785-H04-1.npz
# Renamed : P102785-K16-1.npz
# Renamed : P102785-F14-8.npz
# Renamed : P102785-D23-2.npz
# Renamed : P102785-A10-7.npz
# Renamed : P102785-A02-7.npz
# Renamed : P102785-K01-9.npz
# Renamed : P102785-C24-5.npz
# Renamed : P102785-H04-9.npz
# Renamed : P102785-D22-8.npz
# Renamed : P102785-A10-8.npz
# Renamed : P102785-C24-8.npz
# Renamed : P102785-J10-1.npz
# Renamed : P102785-G08-1.npz
# Renamed : P102785-A19-9.npz
# Renamed : P102785-A02-9.npz
# Renamed : P102785-I08-5.npz
# Renamed : P102785-K16-9.npz
# Renamed : P102785-K23-4.npz
# Renamed : P102785-F12-3.npz
# Renamed : P102785-K21-4.npz
# Renamed : P102785-E06-2.npz
# Renamed : P102785-D19-3.npz
# Renamed : P102785-C24-3.npz
# Renamed : P102785-G11-2.npz
# Renamed : P102785-F09-8.npz
# Renamed : P102785-I10-1.npz
# Renamed : P102785-J12-9.npz
# Renamed : P102785-K16-7.npz
# Renamed : P102785-A10-5.npz
# Renamed : P102785-K16-5.npz
# Renamed : P102785-C05-3.npz
# Renamed : P102785-G08-7.npz
# Renamed : P102785-K01-3.npz
# Renamed : P102785-H04-2.npz
# Renamed : P102785-I08-6.npz
# Renamed : P102785-G20-3.npz
# Renamed : P102785-L20-3.npz
# Renamed : P102785-F17-9.npz
# Renamed : P102785-D21-3.npz
# Renamed : P102785-F15-4.npz
# Renamed : P102785-F03-8.npz
# Renamed : P102785-I06-1.npz
# Renamed : P102785-I24-3.npz
# Renamed : P102785-A02-1.npz
# Renamed : P102785-A02-2.npz
# Renamed : P102785-K01-1.npz
# Renamed : P102785-D06-5.npz
# Renamed : P102785-A02-4.npz
# Renamed : P102785-L07-6.npz
# Renamed : P102785-I10-4.npz
# Renamed : P102785-J10-9.npz
# Renamed : P102785-G20-7.npz
# Renamed : P102785-I10-9.npz
# Renamed : P102785-D22-2.npz
# Renamed : P102785-F10-5.npz
# Renamed : P102785-D21-9.npz
# Renamed : P102785-F15-9.npz
# Renamed : P102785-N12-7.npz
# Renamed : P102785-N13-2.npz
# Renamed : P102785-N16-1.npz
# Renamed : P102785-N17-2.npz
# Renamed : P102785-O15-4.npz
# Renamed : P102785-O15-7.npz
# Renamed : P102785-O15-9.npz
# Renamed : P102785-P04-3.npz
# Renamed : P102785-P04-9.npz
# Renamed : P102785-P10-3.npz
# Renamed : P102785-P10-8.npz
# Renamed : P102785-P21-1.npz
# Renamed : P102785-J12-3.npz
# Renamed : P102785-K17-5.npz
# Renamed : P102785-G08-5.npz
# Renamed : P102785-D06-2.npz
# Renamed : P102785-C05-6.npz
# Renamed : P102785-H18-7.npz
# Renamed : P102785-F12-1.npz
# Renamed : P102785-K02-1.npz
# Renamed : P102785-F14-4.npz
# Renamed : P102785-M13-4.npz
# Renamed : P102785-M13-3.npz
# Renamed : P102785-F09-3.npz
# Renamed : P102785-L07-2.npz
# Renamed : P102785-K02-9.npz
# Renamed : P102785-F16-4.npz
# Renamed : P102785-K16-2.npz
# Renamed : P102785-L07-8.npz
# Renamed : P102785-D23-3.npz
# Renamed : P102785-C10-1.npz
# Renamed : P102785-K23-9.npz
# Renamed : P102785-D21-2.npz
# Renamed : P102785-C15-2.npz
# Renamed : P102785-C15-9.npz
# Renamed : P102785-F10-2.npz
# Renamed : P102785-E03-6.npz
# Renamed : P102785-C24-7.npz
# Renamed : P102785-A19-1.npz
# Renamed : P102785-J13-9.npz
# Renamed : P102785-K02-6.npz
# Renamed : P102785-G08-8.npz
# Renamed : P102785-D23-7.npz
# Renamed : P102785-M09-9.npz
# Renamed : P102785-I08-8.npz
# Renamed : P102785-D06-3.npz
# Renamed : P102785-M10-4.npz
# Renamed : P102785-M10-2.npz
# Renamed : P102785-F09-2.npz
# Renamed : P102785-F14-6.npz
# Renamed : P102785-K21-9.npz
# Renamed : P102785-J13-6.npz
# Renamed : P102785-G11-9.npz
# Renamed : P102785-C24-4.npz
# Renamed : P102785-J13-2.npz
# Renamed : P102785-I06-8.npz
# Renamed : P102785-I06-4.npz
# Renamed : P102785-A02-8.npz
# Renamed : P102785-B07-2.npz
# Renamed : P102785-F15-1.npz
# Renamed : P102785-G11-7.npz
# Renamed : P102785-K21-1.npz
# Renamed : P102785-G24-8.npz
# Renamed : P102785-C05-5.npz
# Renamed : P102785-F14-1.npz
# Renamed : P102785-G24-2.npz
# Renamed : P102785-J10-3.npz
# Renamed : P102785-G24-4.npz
# Renamed : P102785-F12-8.npz
# Renamed : P102785-F16-8.npz
# Renamed : P102785-J24-5.npz
# Renamed : P102785-C15-5.npz
# Renamed : P102785-E12-7.npz
# Renamed : P102785-K21-8.npz
# Renamed : P102785-H22-9.npz
# Renamed : P102785-E03-5.npz
# Renamed : P102785-N12-9.npz
# Renamed : P102785-N17-6.npz
# Renamed : P102785-O15-1.npz
# Renamed : P102785-O21-5.npz
# Renamed : P102785-O21-7.npz
# Renamed : P102785-P09-6.npz
# Renamed : P102785-P09-8.npz
# Renamed : P102785-P21-7.npz
# Renamed : P102785-N12-4.npz
# Renamed : P102785-K21-6.npz
# Renamed : P102785-F12-5.npz
# Renamed : P102785-C15-7.npz
# Renamed : P102785-E12-5.npz
# Renamed : P102785-C05-8.npz
# Renamed : P102785-D19-2.npz
# Renamed : P102785-H18-9.npz
# Renamed : P102785-F14-7.npz
# Renamed : P102785-G24-5.npz
# Renamed : P102785-E03-4.npz
# Renamed : P102785-K01-4.npz
# Renamed : P102785-N16-3.npz
# Renamed : P102785-K17-1.npz
# Renamed : P102785-F10-3.npz
# Renamed : P102785-B07-6.npz
# Renamed : P102785-F03-9.npz
# Renamed : P102785-C10-9.npz
# Renamed : P102785-I06-9.npz
# Renamed : P102785-P03-2.npz
# Renamed : P102785-L05-7.npz
# Renamed : P102785-G20-4.npz
# Renamed : P102785-J24-1.npz
# Renamed : P102785-K23-6.npz
# Renamed : P102785-F09-6.npz
# Renamed : P102785-H22-4.npz
# Renamed : P102785-F03-5.npz
# Renamed : P102785-N13-7.npz
# Renamed : P102785-D06-9.npz
# Renamed : P102785-K16-3.npz
# Renamed : P102785-H18-4.npz
# Renamed : P102785-B07-1.npz
# Renamed : P102785-I10-8.npz
# Renamed : P102785-D06-7.npz
# Renamed : P102785-J12-7.npz
# Renamed : P102785-B07-8.npz
# Renamed : P102785-K02-4.npz
# Renamed : P102785-G22-4.npz
# Renamed : P102785-N16-8.npz
# Renamed : P102785-P03-6.npz
# Renamed : P102785-A10-3.npz
# Renamed : P102785-G11-8.npz
# Renamed : P102785-J10-7.npz
# Renamed : P102785-B07-4.npz
# Renamed : P102785-K16-8.npz
# Renamed : P102785-F16-2.npz
# Renamed : P102785-G20-5.npz
# Renamed : P102785-N17-7.npz
# Renamed : P102785-G11-1.npz
# Renamed : P102785-L07-7.npz
# Renamed : P102785-G11-5.npz
# Renamed : P102785-F17-5.npz
# Renamed : P102785-E12-2.npz
# Renamed : P102785-N16-4.npz
# Renamed : P102785-P03-1.npz
# Renamed : P102785-G11-6.npz
# Renamed : P102785-A10-4.npz
# Renamed : P102785-M10-3.npz
# Renamed : P102785-D22-3.npz
# Renamed : P102785-A19-2.npz
# Renamed : P102785-D22-4.npz
# Renamed : P102785-O15-8.npz
# Renamed : P102785-K16-4.npz
# Renamed : P102785-M10-9.npz
# Renamed : P102785-P09-1.npz
# Renamed : P102785-P09-5.npz
# Renamed : P102785-P10-7.npz
# Renamed : P102785-P10-9.npz
# Renamed : P102785-P21-6.npz
# Renamed : P102785-D06-6.npz
# Renamed : P102785-D22-5.npz
# Renamed : P102785-F15-5.npz
# Renamed : P102785-F10-4.npz
# Renamed : P102785-O21-1.npz
# Renamed : P102785-D23-4.npz
# Renamed : P102785-K17-3.npz
# Renamed : P102785-M13-5.npz
# Renamed : P102785-L05-1.npz
# Renamed : P102785-A19-3.npz
# Renamed : P102785-G22-9.npz
# Renamed : P102785-C15-8.npz
# Renamed : P102785-K17-2.npz
# Renamed : P102785-O21-2.npz
# Renamed : P102785-L19-3.npz
# Renamed : P102785-M09-6.npz
# Renamed : P102785-M13-8.npz
# Renamed : P102785-F16-6.npz
# Renamed : P102785-J10-2.npz
# Renamed : P102785-G20-9.npz
# Renamed : P102785-D21-8.npz
# Renamed : P102785-F09-7.npz
# Renamed : P102785-N16-9.npz
# Renamed : P102785-F09-1.npz
# Renamed : P102785-F15-6.npz
# Renamed : P102785-P03-4.npz
# Renamed : P102785-C05-4.npz
# Renamed : P102785-I24-4.npz
# Renamed : P102785-C15-3.npz
# Renamed : P102785-O21-8.npz
# Renamed : P102785-F16-3.npz
# Renamed : P102785-P03-7.npz
# Renamed : P102785-M13-1.npz
# Renamed : P102785-D21-7.npz
# Renamed : P102785-I08-1.npz
# Renamed : P102785-M09-8.npz
# Renamed : P102785-L20-9.npz
# Renamed : P102785-G08-2.npz
# Renamed : P102785-N13-3.npz
# Renamed : P102785-J24-2.npz
# Renamed : P102785-F03-2.npz
# Renamed : P102785-E06-4.npz
# Renamed : P102785-H04-4.npz
# Renamed : P102785-P03-8.npz
# Renamed : P102785-D23-9.npz
# Renamed : P102785-L05-2.npz
# Renamed : P102785-G08-6.npz
# Renamed : P102785-P04-6.npz
# Renamed : P102785-F15-7.npz
# Renamed : P102785-L19-2.npz
# Renamed : P102785-C10-7.npz
# Renamed : P102785-H04-5.npz
# Renamed : P102785-H18-6.npz
# Renamed : P102785-F03-1.npz
# Renamed : P102785-A10-2.npz
# Renamed : P102785-N12-6.npz
# Renamed : P102785-N16-2.npz
# Renamed : P102785-M10-6.npz
# Renamed : P102785-G24-1.npz
# Renamed : P102785-I24-6.npz
# Renamed : P102785-A10-9.npz
# Renamed : P102785-F17-2.npz
# Renamed : P102785-D19-1.npz
# Renamed : P102785-F14-2.npz
# Renamed : P102785-P09-3.npz
# Renamed : P102785-P10-4.npz
# Renamed : P102785-P21-9.npz
